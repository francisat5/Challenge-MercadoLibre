# %%
import requests
import json
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
url = 'https://api.mercadolibre.com/sites/MLA/search?q=chromecast&limit=50#json'
response = requests.get(url)
data=response.json()
aux=data["results"]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&#39;site_id&#39;: &#39;MLA&#39;, &#39;country_default_time_zone&#39;: &#39;GMT-03:00&#39;, &#39;query&#39;: &#39;chromecast&#39;, &#39;paging&#39;: {&#39;total&#39;: 231, &#39;primary_results&#39;: 231, &#39;offset&#39;: 0, &#39;limit&#39;: 50}, &#39;results&#39;: [{&#39;id&#39;: &#39;MLA879419151&#39;, &#39;site_id&#39;: &#39;MLA&#39;, &#39;title&#39;: &#39;Google Chromecast 3.ª Generación Full Hd Carbón&#39;, &#39;seller&#39;: {&#39;id&#39;: 512225720, &#39;permalink&#39;: &#39;http://perfil.mercadolibre.com.ar/BRIMMERST&#39;, &#39;registration_date&#39;: &#39;2020-01-09T14:13:47.000-04:00&#39;, &#39;car_dealer&#39;: False, &#39;real_estate_agency&#39;: False, &#39;tags&#39;: [&#39;normal&#39;, &#39;eshop&#39;, &#39;mshops&#39;, &#39;messages_as_seller&#39;], &#39;eshop&#39;: {&#39;seller&#39;: 512225720, &#39;eshop_rubro&#39;: None, &#39;eshop_id&#39;: 436767, &#39;nick_name&#39;: &#39;BRIMMERST&#39;, &#39;site_id&#39;: &#39;MLA&#39;, &#39;eshop_logo_url&#39;: &#39;http://http2.mlstatic.com/eshops-logo/512225720v4fbfdb.png&#39;, &#39;eshop_status_id&#39;: 1, &#39;eshop_experience&#39;: 0, &#39;eshop_locations&#39;: []}, &#39;seller_reputation&#39;: {&#39;power_seller_status&#39;: &#39;platinum&#39;, &#39;level_id&#39;: &#39;5_green&#39;, &#39;metrics&#39;: {&#39;cancellations&#39;: {&#39;period&#39;: &#39;60 days&#39;, &#39;rate&#39;: 0, &#39;value&#39;: 0}, &#39;claims&#39;: {&#39;period&#39;: &#39;60 days&#39;, &#39;rate&#39;: 0.0059, &#39;value&#39;: 3}, &#39;delayed_handling_time&#39;: {&#39;period&#39;: &#39;60 days&#39;, &#39;rate&#39;: 0, &#39;value&#39;: 0}, &#39;sales&#39;: {&#39;period&#39;: &#39;60 days&#39;, &#39;completed&#39;: 490}}, &#39;transactions&#39;: {&#39;canceled&#39;: 138, &#39;period&#39;: &#39;historic&#39;, &#39;total&#39;: 4054, &#39;ratings&#39;: {&#39;negative&#39;: 0.01, &#39;neutral&#39;: 0.04, &#39;positive&#39;: 0.95}, &#39;completed&#39;: 3916}}}, &#39;price&#39;: 11200, &#39;prices&#39;: {&#39;id&#39;: &#39;MLA879419151&#39;, &#39;prices&#39;: [{&#39;id&#39;: &#39;131&#39;, &#39;type&#39;: &#39;standard&#39;, &#39;amount&#39;: 11200, &#39;regular_amount&#39;: None, &#39;currency_id&#39;: &#39;ARS&#39;, &#39;last_updated&#39;: &#39;2022-07-30T22:14:57Z&#39;, &#39;conditions&#39;: {&#39;context_restrictions&#39;: [], &#39;start_time&#39;: None, &#39;end_time&#39;: None, &#39;eligible&#39;: True}, &#39;exchange_rate_context&#39;: &#39;DEFAULT&#39;, &#39;metadata&#39;: {}}], &#39;presentation&#39;: {&#39;display_currency&#39;: &#39;ARS&#39;}, &#39;payment_method_prices&#39;: [{&#39;id&#39;: &#39;48e8647a-f83c-4176-be4b-8e2b92b445b1&#39;, &#39;conditions&#39;: {&#39;allowed_methods&#39;: [{&#39;id&#39;: &#39;consumer_credits&#39;, &#39;issuer_id&#39;: 2032, &#39;payment_type_id&#39;: &#39;digital_currency&#39;, &#39;installments&#39;: None}], &#39;start_time&#39;: &#39;2022-08-01T03:00:00Z&#39;, &#39;end_time&#39;: &#39;2022-08-08T03:00:00Z&#39;, &#39;restricted_to_prices&#39;: []}, &#39;value&#39;: 5, &#39;type&#39;: &#39;percentage&#39;, &#39;currency_id&#39;: None, &#39;metadata&#39;: {&#39;purchase_discount_id&#39;: &#39;MLA1081001&#39;, &#39;purchase_discount_type&#39;: &#39;BD&#39;, &#39;purchase_discount_campaign_id&#39;: &#39;P-MLA6946008&#39;, &#39;purchase_discount_rebate_id&#39;: &#39;OFFER-MLA879419151-328524367&#39;}, &#39;exchange_rate_context&#39;: &#39;DEFAULT&#39;}], &#39;reference_prices&#39;: [{&#39;id&#39;: &#39;120&#39;, &#39;type&#39;: &#39;min_standard&#39;, &#39;conditions&#39;: {&#39;context_restrictions&#39;: [&#39;channel_marketplace&#39;], &#39;start_time&#39;: None, &#39;end_time&#39;: None, &#39;eligible&#39;: True}, &#39;amount&#39;: 5449, &#39;currency_id&#39;: &#39;ARS&#39;, &#39;exchange_rate_context&#39;: &#39;DEFAULT&#39;, &#39;tags&#39;: [], &#39;last_updated&#39;: &#39;2022-06-11T06:35:58Z&#39;}, {&#39;id&#39;: &#39;121&#39;, &#39;type&#39;: &#39;was&#39;, &#39;conditions&#39;: {&#39;context_restrictions&#39;: [&#39;channel_marketpla ...

# %%
listaId = []
for item in aux:
    listaId.append(list(item.values())[0])
print(listaId)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;MLA879419151&#39;, &#39;MLA1149162738&#39;, &#39;MLA1149162437&#39;, &#39;MLA1148478656&#39;, &#39;MLA1126587059&#39;, &#39;MLA1148861181&#39;, &#39;MLA1117413521&#39;, &#39;MLA1133995390&#39;, &#39;MLA841943795&#39;, &#39;MLA1131067350&#39;, &#39;MLA828850331&#39;, &#39;MLA870030387&#39;, &#39;MLA770888944&#39;, &#39;MLA914385329&#39;, &#39;MLA906348632&#39;, &#39;MLA880660416&#39;, &#39;MLA1119928088&#39;, &#39;MLA640197868&#39;, &#39;MLA791209336&#39;, &#39;MLA919397138&#39;, &#39;MLA770868685&#39;, &#39;MLA1130644137&#39;, &#39;MLA681763581&#39;, &#39;MLA1108755934&#39;, &#39;MLA934270127&#39;, &#39;MLA781038624&#39;, &#39;MLA1134018363&#39;, &#39;MLA763378349&#39;, &#39;MLA606552113&#39;, &#39;MLA921672238&#39;, &#39;MLA781038431&#39;, &#39;MLA885133507&#39;, &#39;MLA770867984&#39;, &#39;MLA615019452&#39;, &#39;MLA1148912376&#39;, &#39;MLA1130305136&#39;, &#39;MLA1144466974&#39;, &#39;MLA1135606667&#39;, &#39;MLA919341056&#39;, &#39;MLA898124332&#39;, &#39;MLA1126131200&#39;, &#39;MLA1124759816&#39;, &#39;MLA914384593&#39;, &#39;MLA763377681&#39;, &#39;MLA1121937411&#39;, &#39;MLA914388347&#39;, &#39;MLA1130318118&#39;, &#39;MLA1142297547&#39;, &#39;MLA1101785073&#39;, &#39;MLA931340608&#39;]
# </div>

# %%
datos = []
for id in listaId:
    url = 'https://api.mercadolibre.com/items/' + id
    response = requests.get(url)
    datos.append(response.json())
    print (response.json())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&#39;id&#39;: &#39;MLA879419151&#39;, &#39;site_id&#39;: &#39;MLA&#39;, &#39;title&#39;: &#39;Google Chromecast 3.ª Generación Full Hd Carbón&#39;, &#39;subtitle&#39;: None, &#39;seller_id&#39;: 512225720, &#39;category_id&#39;: &#39;MLA352001&#39;, &#39;official_store_id&#39;: None, &#39;price&#39;: 11200, &#39;base_price&#39;: 11200, &#39;original_price&#39;: None, &#39;currency_id&#39;: &#39;ARS&#39;, &#39;initial_quantity&#39;: 2633, &#39;available_quantity&#39;: 50, &#39;sold_quantity&#39;: 500, &#39;sale_terms&#39;: [{&#39;id&#39;: &#39;WARRANTY_TYPE&#39;, &#39;name&#39;: &#39;Tipo de garantía&#39;, &#39;value_id&#39;: &#39;2230280&#39;, &#39;value_name&#39;: &#39;Garantía del vendedor&#39;, &#39;value_struct&#39;: None, &#39;values&#39;: [{&#39;id&#39;: &#39;2230280&#39;, &#39;name&#39;: &#39;Garantía del vendedor&#39;, &#39;struct&#39;: None}]}, {&#39;id&#39;: &#39;WARRANTY_TIME&#39;, &#39;name&#39;: &#39;Tiempo de garantía&#39;, &#39;value_id&#39;: None, &#39;value_name&#39;: &#39;12 meses&#39;, &#39;value_struct&#39;: {&#39;number&#39;: 12, &#39;unit&#39;: &#39;meses&#39;}, &#39;values&#39;: [{&#39;id&#39;: None, &#39;name&#39;: &#39;12 meses&#39;, &#39;struct&#39;: {&#39;number&#39;: 12, &#39;unit&#39;: &#39;meses&#39;}}]}, {&#39;id&#39;: &#39;INVOICE&#39;, &#39;name&#39;: &#39;Facturación&#39;, &#39;value_id&#39;: &#39;6891885&#39;, &#39;value_name&#39;: &#39;Factura A&#39;, &#39;value_struct&#39;: None, &#39;values&#39;: [{&#39;id&#39;: &#39;6891885&#39;, &#39;name&#39;: &#39;Factura A&#39;, &#39;struct&#39;: None}]}], &#39;buying_mode&#39;: &#39;buy_it_now&#39;, &#39;listing_type_id&#39;: &#39;gold_special&#39;, &#39;start_time&#39;: &#39;2020-09-18T17:42:33.000Z&#39;, &#39;stop_time&#39;: &#39;2040-09-13T04:00:00.000Z&#39;, &#39;condition&#39;: &#39;new&#39;, &#39;permalink&#39;: &#39;https://articulo.mercadolibre.com.ar/MLA-879419151-google-chromecast-3-generacion-full-hd-carbon-_JM&#39;, &#39;thumbnail_id&#39;: &#39;620605-MLA32691559317_102019&#39;, &#39;thumbnail&#39;: &#39;http://http2.mlstatic.com/D_620605-MLA32691559317_102019-I.jpg&#39;, &#39;secure_thumbnail&#39;: &#39;https://http2.mlstatic.com/D_620605-MLA32691559317_102019-I.jpg&#39;, &#39;pictures&#39;: [{&#39;id&#39;: &#39;620605-MLA32691559317_102019&#39;, &#39;url&#39;: &#39;http://http2.mlstatic.com/D_620605-MLA32691559317_102019-O.jpg&#39;, &#39;secure_url&#39;: &#39;https://http2.mlstatic.com/D_620605-MLA32691559317_102019-O.jpg&#39;, &#39;size&#39;: &#39;387x500&#39;, &#39;max_size&#39;: &#39;906x1170&#39;, &#39;quality&#39;: &#39;&#39;}, {&#39;id&#39;: &#39;693792-MLA32782022240_112019&#39;, &#39;url&#39;: &#39;http://http2.mlstatic.com/D_693792-MLA32782022240_112019-O.jpg&#39;, &#39;secure_url&#39;: &#39;https://http2.mlstatic.com/D_693792-MLA32782022240_112019-O.jpg&#39;, &#39;size&#39;: &#39;500x398&#39;, &#39;max_size&#39;: &#39;960x766&#39;, &#39;quality&#39;: &#39;&#39;}, {&#39;id&#39;: &#39;701603-MLA32691559322_102019&#39;, &#39;url&#39;: &#39;http://http2.mlstatic.com/D_701603-MLA32691559322_102019-O.jpg&#39;, &#39;secure_url&#39;: &#39;https://http2.mlstatic.com/D_701603-MLA32691559322_102019-O.jpg&#39;, &#39;size&#39;: &#39;247x500&#39;, &#39;max_size&#39;: &#39;536x1082&#39;, &#39;quality&#39;: &#39;&#39;}], &#39;video_id&#39;: None, &#39;descriptions&#39;: [], &#39;accepts_mercadopago&#39;: True, &#39;non_mercado_pago_payment_methods&#39;: [], &#39;shipping&#39;: {&#39;mode&#39;: &#39;me2&#39;, &#39;methods&#39;: [], &#39;tags&#39;: [&#39;self_service_in&#39;, &#39;mandatory_free_shipping&#39;], &#39;dimensions&#39;: None, &#39;local_pick_up&#39;: False, &#39;free_shipping&#39;: True, &#39;logistic_type&#39;: &#39;fulfillment&#39;, &#39;store_pick_up&#39;: False}, &#39;international_delivery_mode&#39;: &#39;none&#39;, &#39;seller_address&#39;: {&#39;city&#39;: {&#39;id&#39;: &#39;TUxBQlNBTjgxMzNa&#39;, &#39;name&#39;: &#39;San Telmo&#39;}, &#39;state&#39;: {&#39;id&#39;: &#39;AR-C&#39;, &#39;name&#39;: &#39 ...

# %%
print (len(datos))
print (datos[0])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">50
# {&#39;id&#39;: &#39;MLA879419151&#39;, &#39;site_id&#39;: &#39;MLA&#39;, &#39;title&#39;: &#39;Google Chromecast 3.ª Generación Full Hd Carbón&#39;, &#39;subtitle&#39;: None, &#39;seller_id&#39;: 512225720, &#39;category_id&#39;: &#39;MLA352001&#39;, &#39;official_store_id&#39;: None, &#39;price&#39;: 11200, &#39;base_price&#39;: 11200, &#39;original_price&#39;: None, &#39;currency_id&#39;: &#39;ARS&#39;, &#39;initial_quantity&#39;: 2633, &#39;available_quantity&#39;: 50, &#39;sold_quantity&#39;: 500, &#39;sale_terms&#39;: [{&#39;id&#39;: &#39;WARRANTY_TYPE&#39;, &#39;name&#39;: &#39;Tipo de garantía&#39;, &#39;value_id&#39;: &#39;2230280&#39;, &#39;value_name&#39;: &#39;Garantía del vendedor&#39;, &#39;value_struct&#39;: None, &#39;values&#39;: [{&#39;id&#39;: &#39;2230280&#39;, &#39;name&#39;: &#39;Garantía del vendedor&#39;, &#39;struct&#39;: None}]}, {&#39;id&#39;: &#39;WARRANTY_TIME&#39;, &#39;name&#39;: &#39;Tiempo de garantía&#39;, &#39;value_id&#39;: None, &#39;value_name&#39;: &#39;12 meses&#39;, &#39;value_struct&#39;: {&#39;number&#39;: 12, &#39;unit&#39;: &#39;meses&#39;}, &#39;values&#39;: [{&#39;id&#39;: None, &#39;name&#39;: &#39;12 meses&#39;, &#39;struct&#39;: {&#39;number&#39;: 12, &#39;unit&#39;: &#39;meses&#39;}}]}, {&#39;id&#39;: &#39;INVOICE&#39;, &#39;name&#39;: &#39;Facturación&#39;, &#39;value_id&#39;: &#39;6891885&#39;, &#39;value_name&#39;: &#39;Factura A&#39;, &#39;value_struct&#39;: None, &#39;values&#39;: [{&#39;id&#39;: &#39;6891885&#39;, &#39;name&#39;: &#39;Factura A&#39;, &#39;struct&#39;: None}]}], &#39;buying_mode&#39;: &#39;buy_it_now&#39;, &#39;listing_type_id&#39;: &#39;gold_special&#39;, &#39;start_time&#39;: &#39;2020-09-18T17:42:33.000Z&#39;, &#39;stop_time&#39;: &#39;2040-09-13T04:00:00.000Z&#39;, &#39;condition&#39;: &#39;new&#39;, &#39;permalink&#39;: &#39;https://articulo.mercadolibre.com.ar/MLA-879419151-google-chromecast-3-generacion-full-hd-carbon-_JM&#39;, &#39;thumbnail_id&#39;: &#39;620605-MLA32691559317_102019&#39;, &#39;thumbnail&#39;: &#39;http://http2.mlstatic.com/D_620605-MLA32691559317_102019-I.jpg&#39;, &#39;secure_thumbnail&#39;: &#39;https://http2.mlstatic.com/D_620605-MLA32691559317_102019-I.jpg&#39;, &#39;pictures&#39;: [{&#39;id&#39;: &#39;620605-MLA32691559317_102019&#39;, &#39;url&#39;: &#39;http://http2.mlstatic.com/D_620605-MLA32691559317_102019-O.jpg&#39;, &#39;secure_url&#39;: &#39;https://http2.mlstatic.com/D_620605-MLA32691559317_102019-O.jpg&#39;, &#39;size&#39;: &#39;387x500&#39;, &#39;max_size&#39;: &#39;906x1170&#39;, &#39;quality&#39;: &#39;&#39;}, {&#39;id&#39;: &#39;693792-MLA32782022240_112019&#39;, &#39;url&#39;: &#39;http://http2.mlstatic.com/D_693792-MLA32782022240_112019-O.jpg&#39;, &#39;secure_url&#39;: &#39;https://http2.mlstatic.com/D_693792-MLA32782022240_112019-O.jpg&#39;, &#39;size&#39;: &#39;500x398&#39;, &#39;max_size&#39;: &#39;960x766&#39;, &#39;quality&#39;: &#39;&#39;}, {&#39;id&#39;: &#39;701603-MLA32691559322_102019&#39;, &#39;url&#39;: &#39;http://http2.mlstatic.com/D_701603-MLA32691559322_102019-O.jpg&#39;, &#39;secure_url&#39;: &#39;https://http2.mlstatic.com/D_701603-MLA32691559322_102019-O.jpg&#39;, &#39;size&#39;: &#39;247x500&#39;, &#39;max_size&#39;: &#39;536x1082&#39;, &#39;quality&#39;: &#39;&#39;}], &#39;video_id&#39;: None, &#39;descriptions&#39;: [], &#39;accepts_mercadopago&#39;: True, &#39;non_mercado_pago_payment_methods&#39;: [], &#39;shipping&#39;: {&#39;mode&#39;: &#39;me2&#39;, &#39;methods&#39;: [], &#39;tags&#39;: [&#39;self_service_in&#39;, &#39;mandatory_free_shipping&#39;], &#39;dimensions&#39;: None, &#39;local_pick_up&#39;: False, &#39;free_shipping&#39;: True, &#39;logistic_type&#39;: &#39;fulfillment&#39;, &#39;store_pick_up&#39;: False}, &#39;international_delivery_mode&#39;: &#39;none&#39;, &#39;seller_address&#39;: {&#39;city&#39;: {&#39;id&#39;: &#39;TUxBQlNBTjgxMzNa&#39;, &#39;name&#39;: &#39;San Telmo&#39;}, &#39;state&#39;: {&#39;id&#39;: &#39;AR-C&#39;, &#39;name&#39;: &#39;Capital Federal&#39; ...

# %%
import pandas as pd
from pandas.io.json import json_normalize
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.functions import col, struct, when
from pyspark.sql.types import StructType, StructField, IntegerType, LongType, StringType, FloatType
 

schema = StructType([StructField("id", StringType(),True),
            StructField("title",StringType(),True),
            StructField("seller_id",StringType(),True),
            StructField("category_id",StringType(),True),
            StructField("price",StringType(),True),
            StructField("base_price",StringType(),True),
            StructField("currency_id",StringType(),True),
            StructField("initial_quantity",StringType(),True),
            StructField("available_quantity",StringType(),True),
            StructField("sold_quantity",StringType(),True),
            StructField("buying_mode",StringType(),True),
            StructField("listing_type_id",StringType(),True),        
            StructField("start_time",StringType(),True),
            StructField("stop_time",StringType(),True),
            StructField("condition",StringType(),True),
            StructField("accepts_mercadopago",StringType(),True),
            StructField("international_delivery_mode",StringType(),True),
            StructField("status",StringType(),True),
            StructField("warranty",StringType(),True),
            StructField("catalog_product_id",StringType(),True),
            StructField("domain_id",StringType(),True),
            StructField("automatic_relist",StringType(),True),
            StructField("date_created",StringType(),True),
            StructField("last_updated",StringType(),True),
            StructField("health",StringType(),True),
            StructField("catalog_listing",StringType(),True)])

#dataframe1
df1 = spark.createDataFrame(datos, schema)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df1.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>title</th><th>seller_id</th><th>category_id</th><th>price</th><th>base_price</th><th>currency_id</th><th>initial_quantity</th><th>available_quantity</th><th>sold_quantity</th><th>buying_mode</th><th>listing_type_id</th><th>start_time</th><th>stop_time</th><th>condition</th><th>accepts_mercadopago</th><th>international_delivery_mode</th><th>status</th><th>warranty</th><th>catalog_product_id</th><th>domain_id</th><th>automatic_relist</th><th>date_created</th><th>last_updated</th><th>health</th><th>catalog_listing</th></tr></thead><tbody><tr><td>MLA879419151</td><td>Google Chromecast 3.ª Generación Full Hd Carbón</td><td>512225720</td><td>MLA352001</td><td>11200</td><td>11200</td><td>ARS</td><td>2633</td><td>50</td><td>500</td><td>buy_it_now</td><td>gold_special</td><td>2020-09-18T17:42:33.000Z</td><td>2040-09-13T04:00:00.000Z</td><td>new</td><td>true</td><td>none</td><td>active</td><td>Garantía del vendedor: 12 meses</td><td>MLA13841393</td><td>MLA-STREAMING_MEDIA_DEVICES</td><td>false</td><td>2020-09-18T17:42:33.000Z</td><td>2022-08-01T14:26:35.219Z</td><td>null</td><td>true</td></tr><tr><td>MLA1149162738</td><td>Google Chromecast With Google Tv De Voz 4k 8gb Snow Con 2gb De Memoria Ram</td><td>360451883</td><td>MLA352001</td><td>21509</td><td>21509</td><td>ARS</td><td>10</td><td>1</td><td>2</td><td>buy_it_now</td><td>gold_special</td><td>2022-08-01T13:07:45.000Z</td><td>2042-07-27T04:00:00.000Z</td><td>new</td><td>true</td><td>none</td><td>active</td><td>Garantía de fábrica: 1 meses</td><td>MLA16233185</td><td>MLA-STREAMING_MEDIA_DEVICES</td><td>false</td><td>2022-08-01T13:07:45.000Z</td><td>2022-08-01T14:32:49.874Z</td><td>null</td><td>true</td></tr><tr><td>MLA1149162437</td><td>Xiaomi Mi Tv Stick Mdz-24-aa De Voz Full Hd 8gb Negro Con 1gb De Memoria Ram</td><td>301416735</td><td>MLA352001</td><td>19985</td><td>19985</td><td>ARS</td><td>4</td><td>1</td><td>1</td><td>buy_it_now</td><td>gold_special</td><td>2022-08-01T12:22:52.000Z</td><td>2042-07-27T04:00:00.000Z</td><td>new</td><td>true</td><td>none</td><td>active</td><td>Sin garantía</td><td>MLA15984003</td><td>MLA-STREAMING_MEDIA_DEVICES</td><td>false</td><td>2022-08-01T12:22:52.000Z</td><td>2022-08-01T14:32:11.389Z</td><td>null</td><td>true</td></tr><tr><td>MLA1148478656</td><td>Xiaomi Mi Box S Mdz-22-ab De Voz 4k 8gb Negro Con 2gb De Memoria Ram</td><td>1065995770</td><td>MLA352001</td><td>24116</td><td>24116</td><td>ARS</td><td>2</td><td>1</td><td>1</td><td>buy_it_now</td><td>gold_special</td><td>2022-07-27T14:24:17.000Z</td><td>2042-07-22T04:00:00.000Z</td><td>new</td><td>true</td><td>none</td><td>active</td><td>Garantía del vendedor: 1 meses</td><td>MLA13877783</td><td>MLA-STREAMING_MEDIA_DEVICES</td><td>false</td><td>2022-07-27T14:24:18.000Z</td><td>2022-08-01T14:32:35.354Z</td><td>null</td><td>true</td></tr><tr><td>MLA1126587059</td><td>Google Chromecast 2.ª Generación Full Hd 256mb Negro Con 512mb De Memoria Ram</td><td>82274172</td><td>MLA352001</td><td>10599</td><td>10599</td><td>ARS</td><td>2203</td><td>500</td><td>500</td><td>buy_it_now</td><td>gold_special</td><td>2022-03-08T21:10:02.000Z</td><td>2042-03-03T04:00:00.000Z</td><td>new</td><td>true</td><td>none</td><td>active</td><td>Garantía del vendedor: 12 meses</td><td>MLA6125039</td><td>MLA-STREAMING_MEDIA_DEVICES</td><td>false</td><td>2022-03-08T21:10:02.000Z</td><td>2022-08-01T14:23:17.962Z</td><td>null</td><td>true</td></tr><tr><td>MLA1148861181</td><td>Xiaomi Stick 4k Mdz-27-aa De Voz 4k 8gb Negro Con 2gb De Memoria Ram</td><td>262582139</td><td>MLA352001</td><td>26499</td><td>26499</td><td>ARS</td><td>150</td><td>100</td><td>0</td><td>buy_it_now</td><td>gold_special</td><td>2022-07-29T17:11:10.000Z</td><td>2042-07-24T04:00:00.000Z</td><td>new</td><td>true</td><td>none</td><td>active</td><td>Garantía de fábrica: 6 meses</td><td>MLA19080742</td><td>MLA-STREAMING_MEDIA_DEVICES</t ...
